# %%
# Data processing packages
import pandas as pd
import numpy as np

#Visualization packages
import matplotlib.pyplot as plt

#NLP packages
from textblob import TextBlob

# %%
#Testing NLP - Sentiment Analysis using TextBlob
TextBlob("The GV camp is very good").sentiment
# Out:
# Sentiment(polarity=0.9099999999999999, subjectivity=0.7800000000000001)

# %%
#Importing YouTube comments data
comm = pd.read_csv("data.csv"); # opening the file data

# %%
#Calculating the Sentiment Polarity
pol=[] # list which will contain the polarity of the comments
for i in comm.comment_text.values:
    try:
        analysis =TextBlob(i)
        pol.append(analysis.sentiment.polarity)
        
    except:
        pol.append(0)

# %%
#Adding the Sentiment Polarity column to the data
comm['pol']=pol

# %%
#Converting the polarity values from continuous to categorical
comm['pol'][comm.pol==0]= 0
comm['pol'][comm.pol > 0]= 1
comm['pol'][comm.pol < 0]= -1
# Out:
# C:\Users\patil\AppData\Local\Temp\ipykernel_41244\1426441482.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comm['pol'][comm.pol==0]= 0
# C:\Users\patil\AppData\Local\Temp\ipykernel_41244\1426441482.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comm['pol'][comm.pol > 0]= 1
# C:\Users\patil\AppData\Local\Temp\ipykernel_41244\1426441482.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comm['pol'][comm.pol < 0]= -1

# %%
#Displaying the POSITIVE comments
df_positive = comm[comm.pol==1]
df_positive.head(15)
# Out:
#        video_id                                       comment_text  likes  \
# 0   jt2OHQh0HoQ  It's more accurate to call it the M+ (1000) be...    0.0
# 4   jt2OHQh0HoQ  Power is the disease.Â  Care is the cure.Â  Ke...    0.0
# 5   jt2OHQh0HoQ  Keep calm and buy iphone 8 Keep calm and buy i...    0.0
# 8   jt2OHQh0HoQ  *APPLE JUST COMMENTED ON MY LAST VIDEO* I'm cr...    0.0
# 10  jt2OHQh0HoQ           Mom said: Just one more video before bed    0.0
# 12  jt2OHQh0HoQ  I started crying at 49:01 when Emma's EP showe...    0.0
# 13  jt2OHQh0HoQ                             more one before to bed    0.0
# 14  jt2OHQh0HoQ                subscribe me if you love your mummy    0.0
# 15  jt2OHQh0HoQ  They really just took the samsung s8 and named...    0.0
# 16  jt2OHQh0HoQ  so if someone has a twin sibling both can unlo...    0.0
# 17  jt2OHQh0HoQ             For god sake its better than my ps4pro    0.0
# 18  jt2OHQh0HoQ     7mp cam what kind of standard is this in 2017?    0.0
# 21  jt2OHQh0HoQ  If apple sucks and samsungs better like this c...    0.0
# 23  jt2OHQh0HoQ            The best thing to ever happen to iPhone    0.0
# 32  jt2OHQh0HoQ  for more information\nhttps://www.youtube.com/...    0.0
#
#     replies  pol
# 0       0.0  1.0
# 4       0.0  1.0
# 5       0.0  1.0
# 8       0.0  1.0
# 10      0.0  1.0
# 12      0.0  1.0
# 13      0.0  1.0
# 14      0.0  1.0
# 15      0.0  1.0
# 16      0.0  1.0
# 17      0.0  1.0
# 18      0.0  1.0
# 21      1.0  1.0
# 23      2.0  1.0
# 32      0.0  1.0

# %%
#Displaying the NEGATIVE comments
df_negative = comm[comm.pol==-1]
df_negative.head(15)
# Out:
#         video_id                                       comment_text  likes  \
# 7    jt2OHQh0HoQ  You will never find Losers who line up and pay...    0.0
# 56   jt2OHQh0HoQ                                       25 Hours WTF    1.0
# 69   jt2OHQh0HoQ                                     fuck you beech    0.0
# 70   jt2OHQh0HoQ                                      piece of shit    0.0
# 81   jt2OHQh0HoQ  Apple is terrible and they only care about the...    0.0
# 87   jt2OHQh0HoQ                       Ill have to sell me for this    0.0
# 92   jt2OHQh0HoQ           Fuck i want this !!! But i have no money    0.0
# 97   YPVcg45W0z4                  awww no fart noise at the end? :(    0.0
# 99   YPVcg45W0z4  I just clicked on this video to say fuck you f...    0.0
# 112  YPVcg45W0z4  you're not intolerant to dairy you're just not...    0.0
# 116  YPVcg45W0z4  so since emma is never gonna die does that mea...    0.0
# 118  YPVcg45W0z4  These tests are antirely useless and give you ...    NaN
# 119  YPVcg45W0z4  well the Vikings did pillage and shag their wa...    0.0
# 142  YPVcg45W0z4       Give me a thumbs up down below \nheu heu heu    NaN
# 147  YPVcg45W0z4                    Now I'm curious about my DNA...    0.0
#
#      replies  pol
# 7        0.0 -1.0
# 56       0.0 -1.0
# 69       1.0 -1.0
# 70       1.0 -1.0
# 81       0.0 -1.0
# 87       1.0 -1.0
# 92       2.0 -1.0
# 97       0.0 -1.0
# 99       0.0 -1.0
# 112      0.0 -1.0
# 116      0.0 -1.0
# 118      NaN -1.0
# 119      0.0 -1.0
# 142      NaN -1.0
# 147      0.0 -1.0

# %%
#Displaying the NEUTRAL comments
df_neutral = comm[comm.pol==0]
df_neutral.head(15)
# Out:
#        video_id                                       comment_text  likes  \
# 1   jt2OHQh0HoQ     To be there with a samsung phone\nðŸ˜‚ðŸ˜‚ðŸ˜‚    1.0
# 2   jt2OHQh0HoQ                                         Thank gosh    NaN
# 3   jt2OHQh0HoQ  What happened to the home button on the iPhone...    0.0
# 6   jt2OHQh0HoQ      i am a big fan of youtube and u !!!!!!!!!!!!!    0.0
# 9   jt2OHQh0HoQ                          I'm only here to see Emma    NaN
# 11  jt2OHQh0HoQ                           what is the song?? 39:20    0.0
# 19  jt2OHQh0HoQ      1:22:13 he was waiting for people to ðŸ‘clap    1.0
# 20  jt2OHQh0HoQ  sarahah has a leak in its system   revealhater...    0.0
# 22  jt2OHQh0HoQ  You Kicks Steve Jobs out the Company;( and do ...    0.0
# 24  jt2OHQh0HoQ  How to internet speed \nVideos \nðŸ‘‡ðŸ‘‡ðŸ‘‡ð...    0.0
# 25  jt2OHQh0HoQ                                  Sub to my channel    0.0
# 26  jt2OHQh0HoQ                        24:57:34 which song is that    1.0
# 27  jt2OHQh0HoQ          Aquele vÃ­deo bem curtinho de 25 horas...    0.0
# 28  jt2OHQh0HoQ        https://www.youtube.com/watch?v=qMW7yXIxnJ0    1.0
# 29  jt2OHQh0HoQ                                     2:47:30 OMGGGG    0.0
#
#     replies  pol
# 1       0.0  0.0
# 2       NaN  0.0
# 3       0.0  0.0
# 6       0.0  0.0
# 9       NaN  0.0
# 11      0.0  0.0
# 19      0.0  0.0
# 20      0.0  0.0
# 22      2.0  0.0
# 24      1.0  0.0
# 25      1.0  0.0
# 26      2.0  0.0
# 27      2.0  0.0
# 28      0.0  0.0
# 29      0.0  0.0

# %%
comm.pol.value_counts()
# Out:
# pol
#  0.0    956
#  1.0    832
# -1.0    226
# Name: count, dtype: int64

# %%
comm.pol.value_counts().plot.bar()
# Out:
# <Axes: xlabel='pol'>

# %%
import matplotlib.pyplot as plt

# Data to plot
labels =  'Neutral', 'Positive', 'negative'
sizes = comm.pol.value_counts()
colors = ['green', 'gold', 'red']
explode = ( 0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
